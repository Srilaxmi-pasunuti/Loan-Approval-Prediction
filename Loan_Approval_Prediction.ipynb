# %%
##Install the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df=pd.read_csv('C:/Users/pasun/OneDrive/Desktop/New folder/dataset.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
pd.set_option('display.max_columns',None)
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
pd.set_option('display.max_columns',None)
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
##check the outliers
plt.figure(figsize=(12,8))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
df['LoanAmount'].median()
# Out:
# np.float64(128.0)

# %%
df['LoanAmount'].mean()
# Out:
# np.float64(146.41216216216216)

# %%
##Filling the null values of numerical datatype
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].median())
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
df['Gender'].mode()[0]
# Out:
# 'Male'

# %%
##Filling the null values of object datatype
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
##checking all the null values are filled or not
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
## Data Visualization
print('Number of people who took loan by gender')
print(df['Gender'].value_counts())
sns.countplot(x='Gender',data=df,palette='Set1')
# Out:
# Number of people who took loan by gender
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64
# <Axes: xlabel='Gender', ylabel='count'>

# %%
print('Number of people who took loan by Married')
print(df['Married'].value_counts())
sns.countplot(x='Married',data=df,palette='Set1')
# Out:
# Number of people who took loan by Married
# Married
# Yes    401
# No     213
# Name: count, dtype: int64
# <Axes: xlabel='Married', ylabel='count'>

# %%
print('Number of people who took loan by Education')
print(df['Education'].value_counts())
sns.countplot(x='Education',data=df,palette='Set1')
# Out:
# Number of people who took loan by Education
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64
# <Axes: xlabel='Education', ylabel='count'>

# %%
print('Number of people who took loan by Self_Employed')
print(df['Self_Employed'].value_counts())
sns.countplot(x='Self_Employed',data=df,palette='Set1')
# Out:
# Number of people who took loan by Self_Employed
# Self_Employed
# No     532
# Yes     82
# Name: count, dtype: int64
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %%
non_numeric_cols=list(df.select_dtypes(exclude=['float','int']).columns)
print(non_numeric_cols)
# Out:
# ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']

# %%
df_numeric=df.select_dtypes(include=['float','int'])

# %%
##Total Applicant Income
df['Total_Income']=df['ApplicantIncome']+df['CoapplicantIncome']
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_Income
# 0             1.0         Urban           Y        5849.0
# ...

# %%
##Apply log Transformation
df['ApplicantIncomelog']=np.log(df['ApplicantIncome']+1)
sns.distplot(df['ApplicantIncomelog'])
# Out:
# <Axes: xlabel='ApplicantIncomelog', ylabel='Density'>

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_Income  ApplicantIncomelog
# 0             1.0         Urban           Y        5849.0            8.674197
# ...

# %%
df['LoanAmountlog']=np.log(df['LoanAmount']+1)
sns.distplot(df['LoanAmountlog'])
# Out:
# <Axes: xlabel='LoanAmountlog', ylabel='Density'>

# %%
df['Loan_Amount_Termlog']=np.log(df['Loan_Amount_Term']+1)
sns.distplot(df['Loan_Amount_Termlog'])
# Out:
# <Axes: xlabel='Loan_Amount_Termlog', ylabel='Density'>

# %%
df['Total_Incomelog']=np.log(df['Total_Income']+1)
sns.distplot(df['Total_Incomelog'])
# Out:
# <Axes: xlabel='Total_Incomelog', ylabel='Density'>

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_Income  ApplicantIncomelog  \
# ...

# %%
##drop unnecessary columns
cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_Income','Loan_ID']
df=df.drop(columns=cols,axis=1)
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  ApplicantIncomelog  LoanAmountlog  \
# 0         Urban           Y            8.674197       4.859812
# 1         Rural           N            8.430327       4.859812
# 2         Urban           Y            8.006701       4.204693
# 3         Urban           Y            7.857094       4.795791
# 4         Urban           Y            8.699681       4.955827
#
#    Loan_Amount_Termlog  Total_Incomelog
# 0             5.888878         8.674197
# 1             5.888878         8.714732
# ...

# %%
##Encoding Technique:Label Encoding,one Hot Encoding
from sklearn.preprocessing import LabelEncoder
cols=['Gender','Married','Education','Dependents','Self_Employed','Property_Area','Loan_Status']
le=LabelEncoder()
for col in cols:
    df[col]=le.fit_transform(df[col])

# %%
##installing sklearn
# !pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
# ...

# %%
##upgrade pip,setuptools,and wheel
# !python -m pip install --upgrade pip
# !python -m pip install --upgrade setuptools wheels
# Out:
# ...
#   Using cached setuptools-75.2.0-py3-none-any.whl.metadata (6.9 kB)
# ERROR: Could not find a version that satisfies the requirement wheels (from versions: none)
# ERROR: No matching distribution found for wheels

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncomelog  LoanAmountlog  \
# 0              2            1            8.674197       4.859812
# 1              0            0            8.430327       4.859812
# 2              2            1            8.006701       4.204693
# 3              2            1            7.857094       4.795791
# 4              2            1            8.699681       4.955827
#
#    Loan_Amount_Termlog  Total_Incomelog
# 0             5.888878         8.674197
# 1             5.888878         8.714732
# ...

# %%
df.dtypes
# Out:
# Gender                   int64
# Married                  int64
# Dependents               int64
# Education                int64
# Self_Employed            int64
# Credit_History         float64
# Property_Area            int64
# Loan_Status              int64
# ApplicantIncomelog     float64
# LoanAmountlog          float64
# Loan_Amount_Termlog    float64
# Total_Incomelog        float64
# dtype: object

# %%
##split Independent and Dependent Feature
x=df.drop(columns=['Loan_Status'],axis=1)
y=df['Loan_Status']

# %%
x
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0             1.0
# 1         1        1           1          0              0             1.0
# 2         1        1           0          0              1             1.0
# 3         1        1           0          1              0             1.0
# 4         1        0           0          0              0             1.0
# ..      ...      ...         ...        ...            ...             ...
# 609       0        0           0          0              0             1.0
# 610       1        1           3          0              0             1.0
# 611       1        1           1          0              0             1.0
# 612       1        1           2          0              0             1.0
# 613       0        0           0          0              1             0.0
#
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
##Logistic Regression
model1=LogisticRegression()
model1.fit(x_train,y_train)
y_pred=model1.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
conf_matrix=confusion_matrix(y_test,y_pred)
class_report=classification_report(y_test,y_pred)
print('Accuracy score of Logistic Regression model:',accuracy*100)
print("confusion_matrix:",conf_matrix)
print("classification report:",class_report)
# Out:
# Accuracy score of Logistic Regression model: 77.27272727272727
# confusion_matrix: [[21 33]
#  [ 2 98]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.91      0.39      0.55        54
#            1       0.75      0.98      0.85       100
#
#     accuracy                           0.77       154
#    macro avg       0.83      0.68      0.70       154
# weighted avg       0.81      0.77      0.74       154

# %%
score=cross_val_score(model1,x,y,cv=5)
score
# Out:
# array([0.81300813, 0.7804878 , 0.7804878 , 0.85365854, 0.81967213])

# %%
np.mean(score)*100
# Out:
# np.float64(80.9462881514061)

# %%
##Decision Tree Classifier
model2=DecisionTreeClassifier()
model2.fit(x_train,y_train)
y_pred=model2.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
conf_matrix=confusion_matrix(y_test,y_pred)
class_report=classification_report(y_test,y_pred)
print('Accuracy score of Decision Tree model:',accuracy*100)
print("confusion_matrix:",conf_matrix)
print("classification report:",class_report)
# Out:
# Accuracy score of Decision Tree model: 71.42857142857143
# confusion_matrix: [[28 26]
#  [18 82]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.61      0.52      0.56        54
#            1       0.76      0.82      0.79       100
#
#     accuracy                           0.71       154
#    macro avg       0.68      0.67      0.67       154
# weighted avg       0.71      0.71      0.71       154

# %%
score=cross_val_score(model2,x,y,cv=5)
print('cross validation score of Decision Tree:',np.mean(score)*100)
# Out:
# cross validation score of Decision Tree: 69.22164467546314

# %%
##Random Forest Classifier
model3=RandomForestClassifier()
model3.fit(x_train,y_train)
y_pred=model3.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
conf_matrix=confusion_matrix(y_test,y_pred)
class_report=classification_report(y_test,y_pred)
print('Accuracy score of Random Forest model:',accuracy*100)
print("confusion_matrix:",conf_matrix)
print("classification report:",class_report)
# Out:
# Accuracy score of Random Forest model: 75.97402597402598
# confusion_matrix: [[22 32]
#  [ 5 95]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.81      0.41      0.54        54
#            1       0.75      0.95      0.84       100
#
#     accuracy                           0.76       154
#    macro avg       0.78      0.68      0.69       154
# weighted avg       0.77      0.76      0.73       154

# %%
##KNeighbor model
model4=KNeighborsClassifier()
model4.fit(x_train,y_train)
y_pred=model4.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
conf_matrix=confusion_matrix(y_test,y_pred)
class_report=classification_report(y_test,y_pred)
print('Accuracy score of KNeighbor model:',accuracy*100)
print("confusion_matrix:",conf_matrix)
print("classification report:",class_report)
# Out:
# Accuracy score of KNeighbor model: 72.72727272727273
# confusion_matrix: [[20 34]
#  [ 8 92]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.71      0.37      0.49        54
#            1       0.73      0.92      0.81       100
#
#     accuracy                           0.73       154
#    macro avg       0.72      0.65      0.65       154
# weighted avg       0.72      0.73      0.70       154

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
##XGBoost classifier
model5=XGBClassifier()
model5.fit(x_train,y_train)
y_pred=model5.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
conf_matrix=confusion_matrix(y_test,y_pred)
class_report=classification_report(y_test,y_pred)
print('Accuracy score of XGBoost model:',accuracy*100)
print("confusion_matrix:",conf_matrix)
print("classification report:",class_report)
# Out:
# Accuracy score of XGBoost model: 77.27272727272727
# confusion_matrix: [[26 28]
#  [ 7 93]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.79      0.48      0.60        54
#            1       0.77      0.93      0.84       100
#
#     accuracy                           0.77       154
#    macro avg       0.78      0.71      0.72       154
# weighted avg       0.78      0.77      0.76       154

# %%
model3=RandomForestClassifier()
model3.fit(x_train,y_train)
y_pred=model3.predict(x_test)
score=cross_val_score(model3,x,y,cv=5)
print('cross validation score of Random forest:',np.mean(score)*100)
# Out:
# cross validation score of Random forest: 78.50459816073571

# %%
import pickle

# %%
pickle.dump(model3,open('model.pkl','wb'))

# %%
model3.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
## saving the model
import joblib

# %%
joblib.dump(model3,'loan_status_predict')
# Out:
# ['loan_status_predict']

# %%
model=joblib.load('loan_status_predict')

# %%
import pandas as pd
df=pd.DataFrame({
    'Gender':1,
    'Married':1,
    'Dependents':2,
    'Education':0,
    'Self_Employed':0,
    'Credit_History':0.0,
    'Property_Area':1,
    'ApplicantIncomelog':7.674197,
    'LoanAmountlog':4.236431,
    'Loan_Amount_Termlog':5.122963,
    'Total_Incomelog':8.6741197
    },index=[0])

# %%
df
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        1           2          0              0             0.0
#
#    Property_Area  ApplicantIncomelog  LoanAmountlog  Loan_Amount_Termlog  \
# 0              1            7.674197       4.236431             5.122963
#
#    Total_Incomelog
# 0          8.67412

# %%
result=model.predict(df)

# %%
if result==1:
    print("Loan Approved")
else:
    print("Loan Rejected")
# Out:
# Loan Rejected

# %%
## GUI
from tkinter import*
import joblib
import pandas as pd

# %%
def show_entry():

    p1=float(e1.get())
    p2=float(e2.get())
    p3=float(e3.get())
    p4=float(e4.get())
    p5=float(e5.get())
    p6=float(e6.get())
    p7=float(e7.get())
    p8=float(e8.get())
    p9=float(e9.get())
    p10=float(e10.get())
    p11=float(e11.get())

    model=joblib.load('loan_status_predict')
    df=pd.DataFrame({
    'Gender':p1,
    'Married':p2,
    'Dependents':p3,
    'Education':p4,
    'Self_Employed':p5,
    'Credit_History':p6,
    'Property_Area':p7,
    'ApplicantIncomelog':p8,
    'LoanAmountlog':p9,
    'Loan_Amount_Termlog':p10,
    'Total_Incomelog':p11
},index=[0])
    result=model.predict(df)

    if result==1:
        Label(master,text="Loan Approved").grid(row=31)
    else:
        Label(master,text="Loan Rejected").grid(row=31)


master=Tk()
master.title("Loan Approval Prediction using machine learning")
label=Label(master,text="Loan Status Prediction",bg="black",fg="white").grid(row=0,columnspan=2)

Label(master,text="Gender [1:Male ,0:Female]").grid(row=1)
Label(master,text="Married [1:Yes ,0:No]").grid(row=2)
Label(master,text="Dependents [1,2,3,4]").grid(row=3)
Label(master,text="Education").grid(row=4)
Label(master,text="Self_Employed").grid(row=5)
Label(master,text="Credit_History").grid(row=6)
Label(master,text="Property_Area").grid(row=7)
Label(master,text="ApplicantIncomelog").grid(row=8)
Label(master,text="LoanAmountlog").grid(row=9)
Label(master,text="Loan_Amount_Termlog").grid(row=10)
Label(master,text="Total_Incomelog").grid(row=11)

e1=Entry(master)
e2=Entry(master)
e3=Entry(master)
e4=Entry(master)
e5=Entry(master)
e6=Entry(master)
e7=Entry(master)
e8=Entry(master)
e9=Entry(master)
e10=Entry(master)
e11=Entry(master)

e1.grid(row=1,column=1)
e2.grid(row=2,column=1)
e3.grid(row=3,column=1)
e4.grid(row=4,column=1)
e5.grid(row=5,column=1)
e6.grid(row=6,column=1)
e7.grid(row=7,column=1)
e8.grid(row=8,column=1)
e9.grid(row=9,column=1)
e10.grid(row=10,column=1)
e11.grid(row=11,column=1)

Button(master,text="predict",command=show_entry).grid()

mainloop()
